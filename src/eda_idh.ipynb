# %%
import pandas as pd
import numpy as np

# %%
# Carregando o dataset
use_cols = ['IDHM 2012','IDHM 2013','IDHM 2014','IDHM 2015','IDHM 2016','IDHM 2017','IDHM 2018','IDHM 2019','IDHM 2020','IDHM 2021',
            'IDHM Renda 2012', 'IDHM Renda 2013', 'IDHM Renda 2014', 'IDHM Renda 2015', 'IDHM Renda 2016', 'IDHM Renda 2017', 
            'IDHM Renda 2018', 'IDHM Renda 2019', 'IDHM Renda 2020', 'IDHM Renda 2021']
df = pd.read_csv('../data/idh.csv', usecols=use_cols)

# %%
# Out:
#    IDHM Renda 2012  IDHM Renda 2013  IDHM Renda 2014  IDHM Renda 2015  \
# 0            0.732            0.737            0.741            0.736
# 1            0.670            0.670            0.669            0.674
# 2            0.627            0.629            0.645            0.636
# 3            0.673            0.691            0.687            0.690
# 4            0.683            0.683            0.683            0.673
#
#    IDHM Renda 2016  IDHM Renda 2017  IDHM Renda 2018  IDHM Renda 2019  \
# 0            0.734            0.735            0.741            0.743
# 1            0.660            0.655            0.676            0.668
# 2            0.637            0.631            0.637            0.636
# 3            0.682            0.683            0.666            0.665
# 4            0.654            0.672            0.655            0.658
#
#    IDHM Renda 2020  IDHM Renda 2021  IDHM 2012  IDHM 2013  IDHM 2014  \
# ...
